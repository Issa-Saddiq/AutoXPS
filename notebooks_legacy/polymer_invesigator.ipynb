# %%
from pathlib import Path

# Define the folder path
folder = Path("../data/experimental_data")

# Get all subfolders (not files)
folders = [f.name for f in folder.iterdir() if f.is_dir()]

# Print them
for dname in folders:
    print(dname)
# Out:
# poly(ether ether ketone) (PEEK)
# poly(vinyl methyl ether) (PVME)
# poly(4-hydroxystyrene) (PHS)
# poly(ethyl methacrylate) (PEMA)
# poly(methyl methacrylate) (PMMA)
# poly(trans-isoprene) (PtI)
# poly(glycolide) (PG)
# Ethylcellulose (ECEL)
# poly(allylamine hydrochloride) (PAAMC)
# poly(trifluoroethyl acrylate) (PTFEA)
# poly(lauryl methacrylate) (PLMA)
# poly(vinyl ethyl ether) (PVEE)
# Nylon 6,6 (N66)
# p-Quaterphenyl [poly(phenylene) oligomer]
# poly(d,l-lactide) (PL)
# poly(ethylene sulphide) (PETHS)
# poly(diallyl isophthalate) (PDAiP)
# poly(vinyl acetate) (PVAc)
# poly(ethylene-co-maleic anhydride) (PECMA)
# poly(methacrylamide) (PMAM)
# poly(propylene glycol) (PPG)
# poly(chloroprene) (PCP)
# poly(4-methyl-1-pentene) (PMP)
# poly(vinylidine chloride) (PVdC)
# poly(4-nitrostyrene) (PNS)
# poly(n-butyl methacrylate) (PnBMA)
# poly(styrene-co-maleic anhydride) (PSCMA)
# poly(tetramethylene glycol) (PTMG)
# poly(2-vinylnaphthalene) (PVN)
# cellulose trinitrate (CTN)
# ...

# %%
import pandas as pd

# Path to the Excel file
file_path = "../data/experimental_data/poly(ethyl methacrylate) (PEMA)/PEMA_FG.xlsx"

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Print the whole DataFrame
print(df)

# Or if it’s very large, show just the first few rows
display(df.head())
# Out:
#       Functional groups  Number
# 0                alkene     NaN
# 1                alkyne     NaN
# 2          benzene ring     NaN
# 3           naphthalene     NaN
# 4                 amine     NaN
# 5    alcohol (aromatic)     NaN
# 6   alcohol (aliphatic)     NaN
# 7      ether (aromatic)     NaN
# 8     ether (aliphatic)     NaN
# 9      alkyl halide (F)     NaN
# 10    alkyl halide (Cl)     NaN
# 11    alkyl halide (Br)     NaN
# 12     alkyl halide (I)     NaN
# 13                thiol     NaN
# 14             aldehyde     NaN
# 15    ketone (aromatic)     NaN
# 16   ketone (aliphatic)     NaN
# 17     ester (aromatic)     NaN
# 18    ester (aliphatic)     1.0
# 19      carboxylic acid     NaN
# 20                amide     NaN
# 21              nitrite     NaN
# 22              nitrate     NaN
# 23              nitrile     NaN
# 24              epoxide     NaN
# 25                imide     NaN
# 26        acid chloride     NaN
# 27            anhydride     NaN
# ...
